# %%
import pandas as pd

# Load the file
df = pd.read_csv('../data/silver/test_set.csv')

filtered_df = df[df['target'] == 0]


# View the first 5 rows
filtered_df.head()
# Out:
#    Attribute2  Attribute5  Attribute8  Attribute11  Attribute13  Attribute16  \
# 0          18        1913           3            3           36            1
# 1          12        1860           4            2           34            2
# 3          18        3104           3            1           31            1
# 5          13         882           4            4           23            2
# 6          18        3612           3            4           37            1
#
#    Attribute18  target  Attribute7_score  Attribute1_A12  ...  \
# 0            1       0                 1            True  ...
# 1            1       0                 0            True  ...
# 3            1       0                 3           False  ...
# 5            1       0                 1            True  ...
# 6            1       0                 4            True  ...
#
#    Attribute12_A124  Attribute14_A142  Attribute14_A143  Attribute15_A152  \
# ...
